# %% [markdown]
# # Немножко повторения

# %%
# 1.1 Создать одномерный массив "a" из 10 элементов со значениями от 0 до 9. Вывести результат
# 1.2 Используя цикл while вывести элементы в обратной последовательности (с 9-го по 0-й элемент)
# 1.3 Вывести элемнеты в обратной последовательности, используя функцию библиотеки numpy

# %%
# 2.1 Создать одномерный массив "b" из 11 элементов.
# 2.2 Используя цикл while заполнить элеметы "b" элемнетами из "a" в обратной последовательности (b[0] = a[9]).
#     10-й элемнет массива b должен быть суммой всех предыдущих его членов.Вывести результат.
# 2.3 Повторить пункт 2.2, совершая все действия только в одном цикле. (То есть в процессе присвоения элементов, 
#     необходимо прибавлять присвоенный элемент в b[10])

# %%
# 3 повторить пункт 2, используя цикл for

# %%
# 4.1 Создать одномерный массив "с" из 10 элементов со значениями от 0 до 9
# 4.2 Создать одномерный массив "d" из 11 элементов.
# 4.3 Используя библиотеку numpy заполнить элеметы "d" элемнетами из "c" в обратной последовательности 
#      (d[0] = c[9]). 10-й элемнет массива d должен быть суммой всех предыдущих его членов.
#      Вывести результат.

# %% [markdown]
# # Чуточку сложнее =)*

# %%
# 1. Нужно создать 2мерный numpy массив A из 10 строк и 5 столбцов. Вывести результат
# 1.1 Используя вложенный цикл for необходимо заполнить все его столбцы значениями,
#     Равными индексу этого столбца. Вывести результат
# 1.2 Вывести сумму всех элементов по столбцам (5 значений)
# 1.3 Вывести сумму всех элементов по строкам (10 значений)

# %%
# 2. Повторить пункт 1 используя numpy
