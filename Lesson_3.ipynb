# %% [markdown]
# # 2. Уже третий урок, ты умничка!

# %% [markdown]
# ### Немножко повторения

# %%
# 1.1. Создать массив "а" из 5-и элементов от 1 до 5
# 1.2. Создать нулевую матрицу "А" из 6-ти строк размер которых равен "а"
# 1.3. Прибавить к каждой строке "А" массив "а"

# %%
# 2.1. Создать нулевую матрицу "В" из 6-ти строк размер которых равен "а"
# 2.2. Прибавить к каждой строке "В" массив "а", все элемнеты которого умножены на 2

# %%
# 3.1. Создать матрицу "С" размера "В". В  матицу "С" должна быть записана поэлементная разница 
#      матриц "В" и "А", возведенная в квадрат
# 3.2 Вывести сумму элемнетов матрицы "С" по трокам, деленную на длинну массива "а"

# %% [markdown]
# ### Функции

# %%
# 4.1  Нужно написать функцию, которая в качесте прараметров принимает 2  матрица и 
#      Возвращает масиив. Функция должна совершать действия, описанные в пункте 3

# %%
# 4.1 Нужно написать функцию, которая возвращает 2 массива (размром "n" и "m").
#     Функция должна создать матрицу размером "10 x 5" и заполнить ее случайными значениями с нормальным 
#     Распределением относитьльно нуля и стандартным отклонением σ = 10. Вернуть функция должна сумму по 
#     строкам и сумму по столбцам

# %%
# 5.1. Копируйте функцию из пункта 4
# 5.2. Измените функцию так, чтобы размер матрицы можно было менять. В качесте прараметров функция 
#      должна принимать форму матрицы (2 элемнета: "n" - количесвто строк и  "m" - количесвто столбцов)
# 5.3. Измените функцию так, чтобы стандартное отклонение σ можно было менять. Должен добавиться еще 
#      один параметр
